# %%
import Unet
import InvertCnnConverter

# %%
plain_model = Unet.UNet(n_channels=1, n_classes=1)

# %%
InvertCnnCov

# %%
result = plain_model(image.view(1,1,320,320))

# %%
rand_data = torch.rand(1,64,320,320)
original_conv2= torch.nn.Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
original_result = original_conv2(rand_data)
print(original_result.shape)
# Out:
# torch.Size([1, 128, 320, 320])

# %%
rand_data = torch.rand(1,1,320,320)
original_conv2= torch.nn.Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
maxpool = torch.nn.MaxPool3d((2,2,2))
conv1 = torch.nn.Conv3d(1, 64, (1,1,1))

x = original_conv2(rand_data)
x = maxpool(x)
x = conv1(x)
print(x.shape)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-31-06f1f65f92bc> in <module>
#       6 x = original_conv2(rand_data)
#       7 x = maxpool(x)
# ----> 8 x = conv1(x)
#       9 print(x.shape)
#
# /opt/conda/envs/memcnn/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /opt/conda/envs/memcnn/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     519                             self.dilation, self.groups)
#     520         return F.conv3d(input, self.weight, self.bias, self.stride,
# ...

# %%
rand_data = torch.rand(1,1,320,320)
m = nn.Upsample(scale_factor=2, mode='bilinear')
conv111= torch.nn.Conv2d(1, 1, 1, padding=0, bias=False)
# Out:
# torch.Size([1, 2, 320, 320])

# %%
mp2 = torch.nn.MaxPool2d((2,2,2))

# %%
rand_data = torch.rand((1,1,320,320))

# %%
conv1 = torch.nn.Conv2d(1, 64, (1,1))
conv1_result = conv1(rand_data)

# %%
conv1_result.shape
# Out:
# torch.Size([1, 64, 320, 320])

# %%
plain_model
# Out:
# UNet(
#   (inc): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (down1): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
from fastmri.data.mri_data import fetch_dir
from fastmri.data.subsample import create_mask_for_mask_type
from fastmri.data.transforms import UnetDataTransform
from fastmri.pl_modules import FastMriDataModule, UnetModule
from fastmri.data import transforms, mri_data
import pathlib
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
CHALLENGE = 'singlecoil'
MASK_TYPE = 'random'
center_fractions = [0.08]
accelerations = [4]


mask = create_mask_for_mask_type(
        MASK_TYPE, center_fractions, accelerations
    )

# %%
train_transform = UnetDataTransform(CHALLENGE, mask_func=mask, use_seed=False)

# %%
dataset = mri_data.SliceDataset(
    root=pathlib.Path(
      './fastmri_data/singlecoil_val'
    ),
    transform=train_transform,
    challenge='singlecoil'
)

# %%
dataloader = torch.utils.data.DataLoader(dataset, batch_size=1)

# %%
image, target, _, _, _, _, _ = next(iter(dataloader))

# %%
image.shape, target.shape
# Out:
# (torch.Size([1, 320, 320]), torch.Size([1, 320, 320]))

# %%
plt.imshow(image.view(320, 320).numpy())

# %%
plt.imshow(target.view(320, 320).numpy())
