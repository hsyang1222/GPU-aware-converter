# %%
from fastmri.data.mri_data import fetch_dir
from fastmri.data.subsample import create_mask_for_mask_type
from fastmri.data.transforms import UnetDataTransform
from fastmri.pl_modules import FastMriDataModule, UnetModule
from fastmri.data import transforms, mri_data
import pathlib
import torch
import matplotlib.pyplot as plt
import numpy as np


CHALLENGE = 'singlecoil'
MASK_TYPE = 'random'
center_fractions = [0.08]
accelerations = [4]


mask = create_mask_for_mask_type(
        MASK_TYPE, center_fractions, accelerations
    )

train_transform = UnetDataTransform(CHALLENGE, mask_func=mask, use_seed=False)

dataset = mri_data.SliceDataset(
    root=pathlib.Path(
      './fastmri_data/singlecoil_val'
    ),
    transform=train_transform,
    challenge='singlecoil'
)

dataloader = torch.utils.data.DataLoader(dataset, batch_size=10)
image, target, _, _, _, _, _ = next(iter(dataloader))

# %%
import InvertCnnConverter
import torch
import Unet

# %%
import importlib
importlib.reload(InvertCnnConverter)
# Out:
# <module 'InvertCnnConverter' from '/home/hsyang/workspace/20210411_SYS/memcnn-unet/InvertCnnConverter.py'>

# %%
plain_model = Unet.UNet(n_channels=1, n_classes=1)

# %%
plain_model
# Out:
# UNet(
#   (inc): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#   )
#   (down1): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU()
#         )
#       )
#     )
#   )
#   (down2): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU()
#         )
#       )
#     )
#   )
#   (down3): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU()
#         )
#       )
#     )
#   )
#   (down4): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU()
#         )
#       )
#     )
#   )
#   (up1): Up(
#     (up): Upsample(scale_factor=2.0, mode=bilinear)
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#       )
#     )
#   )
#   (up2): Up(
#     (up): Upsample(scale_factor=2.0, mode=bilinear)
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#       )
#     )
#   )
#   (up3): Up(
#     (up): Upsample(scale_factor=2.0, mode=bilinear)
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#       )
#     )
#   )
#   (up4): Up(
#     (up): Upsample(scale_factor=2.0, mode=bilinear)
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#       )
#     )
#   )
#   (outc): OutConv(
#     (conv): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
#InvertCnnConverter.top_forward_to_checkpoint(plain_model, last_module_name='outc')
InvertCnnConverter.convert_module(plain_model, last_module_name='outc', inplace=True)
invert_model = plain_model

device = 'cuda:0'

invert_model = invert_model.to(device)
data = image.view(-1,1,320,320).to(device)
target = target.to(device)

print(invert_model)
# Out:
# UNet(
#   (inc): CheckpointModule(
#     (module): DoubleConv(
#       (double_conv): Sequential(
#         (0): UpInvertibleBlock(
#           (upscale): Upsample(scale_factor=(8.0, 8.0), mode=bilinear)
#           (conv2): InvertibleModuleWrapper(
#             (_fn): AdditiveCoupling(
#               (Gm): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (Fm): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#         )
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): InvertibleModuleWrapper(
#           (_fn): AdditiveCoupling(
#             (Gm): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (Fm): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#       )
#     )
#   )
#   (down1): CheckpointModule(
#     (module): Down(
#       (maxpool_conv): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): DoubleConv(
#           (double_conv): Sequential(
#             (0): UpInvertibleBlock(
#               (upscale): Upsample(scale_factor=(2.0, 1.0), mode=bilinear)
#               (conv2): InvertibleModuleWrapper(
#                 (_fn): AdditiveCoupling(
#                   (Gm): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (Fm): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 )
#               )
#             )
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU()
#             (3): InvertibleModuleWrapper(
#               (_fn): AdditiveCoupling(
#                 (Gm): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (Fm): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (5): ReLU()
#           )
#         )
#       )
#     )
#   )
#   (down2): CheckpointModule(
#     (module): Down(
#       (maxpool_conv): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): DoubleConv(
#           (double_conv): Sequential(
#             (0): UpInvertibleBlock(
#               (upscale): Upsample(scale_factor=(2.0, 1.0), mode=bilinear)
#               (conv2): InvertibleModuleWrapper(
#                 (_fn): AdditiveCoupling(
#                   (Gm): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (Fm): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 )
#               )
#             )
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU()
#             (3): InvertibleModuleWrapper(
#               (_fn): AdditiveCoupling(
#                 (Gm): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (Fm): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#             (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (5): ReLU()
#           )
#         )
#       )
#     )
#   )
#   (down3): CheckpointModule(
#     (module): Down(
#       (maxpool_conv): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): DoubleConv(
#           (double_conv): Sequential(
#             (0): UpInvertibleBlock(
#               (upscale): Upsample(scale_factor=(2.0, 1.0), mode=bilinear)
#               (conv2): InvertibleModuleWrapper(
#                 (_fn): AdditiveCoupling(
#                   (Gm): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (Fm): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 )
#               )
#             )
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU()
#             (3): InvertibleModuleWrapper(
#               (_fn): AdditiveCoupling(
#                 (Gm): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (Fm): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (5): ReLU()
#           )
#         )
#       )
#     )
#   )
#   (down4): CheckpointModule(
#     (module): Down(
#       (maxpool_conv): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): DoubleConv(
#           (double_conv): Sequential(
#             (0): InvertibleModuleWrapper(
#               (_fn): AdditiveCoupling(
#                 (Gm): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (Fm): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU()
#             (3): InvertibleModuleWrapper(
#               (_fn): AdditiveCoupling(
#                 (Gm): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (Fm): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (5): ReLU()
#           )
#         )
#       )
#     )
#   )
#   (up1): CheckpointModule(
#     (module): Up(
#       (up): Upsample(scale_factor=2.0, mode=bilinear)
#       (conv): DoubleConv(
#         (double_conv): Sequential(
#           (0): RestoreClass(StitchableConv2d(in_channel=1024, out_channel=512, kernel=3, stride=1, padding=1, fetch_shape=[128, 128])
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): DownInvertibleBlock(
#             (conv2): InvertibleModuleWrapper(
#               (_fn): AdditiveCoupling(
#                 (Gm): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (Fm): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#             (down_channel): MaxPool3d(kernel_size=(2, 1, 1), stride=(2, 1, 1), padding=0, dilation=1, ceil_mode=False)
#           )
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU()
#         )
#       )
#     )
#   )
#   (up2): CheckpointModule(
#     (module): Up(
#       (up): Upsample(scale_factor=2.0, mode=bilinear)
#       (conv): DoubleConv(
#         (double_conv): Sequential(
#           (0): DownInvertibleBlock(
#             (conv2): InvertibleModuleWrapper(
#               (_fn): AdditiveCoupling(
#                 (Gm): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (Fm): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#             (down_channel): MaxPool3d(kernel_size=(2, 1, 1), stride=(2, 1, 1), padding=0, dilation=1, ceil_mode=False)
#           )
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): DownInvertibleBlock(
#             (conv2): InvertibleModuleWrapper(
#               (_fn): AdditiveCoupling(
#                 (Gm): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (Fm): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#             (down_channel): MaxPool3d(kernel_size=(2, 1, 1), stride=(2, 1, 1), padding=0, dilation=1, ceil_mode=False)
#           )
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU()
#         )
#       )
#     )
#   )
#   (up3): CheckpointModule(
#     (module): Up(
#       (up): Upsample(scale_factor=2.0, mode=bilinear)
#       (conv): DoubleConv(
#         (double_conv): Sequential(
#           (0): DownInvertibleBlock(
#             (conv2): InvertibleModuleWrapper(
#               (_fn): AdditiveCoupling(
#                 (Gm): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (Fm): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#             (down_channel): MaxPool3d(kernel_size=(2, 1, 1), stride=(2, 1, 1), padding=0, dilation=1, ceil_mode=False)
#           )
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): DownInvertibleBlock(
#             (conv2): InvertibleModuleWrapper(
#               (_fn): AdditiveCoupling(
#                 (Gm): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (Fm): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#             (down_channel): MaxPool3d(kernel_size=(2, 1, 1), stride=(2, 1, 1), padding=0, dilation=1, ceil_mode=False)
#           )
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU()
#         )
#       )
#     )
#   )
#   (up4): CheckpointModule(
#     (module): Up(
#       (up): Upsample(scale_factor=2.0, mode=bilinear)
#       (conv): DoubleConv(
#         (double_conv): Sequential(
#           (0): DownInvertibleBlock(
#             (conv2): InvertibleModuleWrapper(
#               (_fn): AdditiveCoupling(
#                 (Gm): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (Fm): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#             (down_channel): MaxPool3d(kernel_size=(2, 1, 1), stride=(2, 1, 1), padding=0, dilation=1, ceil_mode=False)
#           )
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): InvertibleModuleWrapper(
#             (_fn): AdditiveCoupling(
#               (Gm): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (Fm): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU()
#         )
#       )
#     )
#   )
#   (outc): OutConv(
#     (conv): DownInvertibleBlock(
#       (conv2): InvertibleModuleWrapper(
#         (_fn): AdditiveCoupling(
#           (Gm): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#           (Fm): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (down_channel): MaxPool3d(kernel_size=(64, 1, 1), stride=(64, 1, 1), padding=0, dilation=1, ceil_mode=False)
#     )
#   )
# )

# %%
criterion = torch.nn.MSELoss()
optim = torch.optim.Adam(invert_model.parameters(), lr=1e-3)
with torch.autograd.set_detect_anomaly(True) : 
    for epoch in range(1000) : 
        result = invert_model(data)
        loss = criterion(result, target)
        optim.zero_grad()
        loss.backward()
        optim.step()
        print(epoch, loss.item())
# Out:
# RestoreClass move forward/backward tensor from cpu to cuda:0
# 	of layer(StitchableConv2d(in_channel=1024, out_channel=512, kernel=3, stride=1, padding=1, fetch_shape=[128, 128])
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=612 / 1315 MB, reserved=1342 / 1342 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=612 / 1315 MB, reserved=1342 / 1342 MB
# 0 11.283251762390137
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3331 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3331 MB, reserved=4220 / 4220 MB
# 1 11.134181022644043
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 2 10.991314888000488
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 3 10.854276657104492
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 4 10.722710609436035
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 5 10.59627628326416
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 6 10.474607467651367
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 7 10.357352256774902
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 8 10.244193077087402
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 9 10.134849548339844
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 10 10.029037475585938
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 11 9.926498413085938
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 12 9.826979637145996
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 13 9.730267524719238
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 14 9.636162757873535
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 15 9.54446029663086
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 16 9.455000877380371
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 17 9.367669105529785
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 18 9.282315254211426
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# 19 9.198821067810059
# # [start] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# # [end  ] StitchableConv2dFunction.forward: stitching
#   alloc=616 / 3335 MB, reserved=4220 / 4220 MB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-dc4987d7d0a9> in <module>
#       3 with torch.autograd.set_detect_anomaly(True) :
#       4     for epoch in range(1000) :
# ----> 5         result = invert_model(data)
#       6         loss = criterion(result, target)
#       7         optim.zero_grad()
#
# /opt/conda/envs/memcnn/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /home/hsyang/workspace/20210411_SYS/memcnn-unet/Unet.py in forward(self, x)
#     105         x = self.up1(x5, x4)
#     106         x = self.up2(x, x3)
# --> 107         x = self.up3(x, x2)
#     108         x = self.up4(x, x1)
#     109         logits = self.outc(x)
#
# /opt/conda/envs/memcnn/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /home/hsyang/workspace/20210411_SYS/memcnn-unet/InvertCnnConverter.py in forward(self, *args)
#     151
#     152     def forward(self, *args) :
# --> 153         return checkpoint(self.module, *args)
#     154
#     155
#
# /opt/conda/envs/memcnn/lib/python3.6/site-packages/torch/utils/checkpoint.py in checkpoint(function, *args, **kwargs)
#     175         raise ValueError("Unexpected keyword arguments: " + ",".join(arg for arg in kwargs))
#     176
# --> 177     return CheckpointFunction.apply(function, preserve, *args)
#     178
#     179
#
# /opt/conda/envs/memcnn/lib/python3.6/site-packages/torch/utils/checkpoint.py in forward(ctx, run_function, preserve_rng_state, *args)
#      73         ctx.save_for_backward(*args)
#      74         with torch.no_grad():
# ---> 75             outputs = run_function(*args)
#      76         return outputs
#      77
#
# /opt/conda/envs/memcnn/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /home/hsyang/workspace/20210411_SYS/memcnn-unet/Unet.py in forward(self, x1, x2)
#      66         # https://github.com/xiaopeng-liao/Pytorch-UNet/commit/8ebac70e633bac59fc22bb5195e513d5832fb3bd
#      67         x = torch.cat([x2, x1], dim=1)
# ---> 68         return self.conv(x)
#      69
#      70
#
# /opt/conda/envs/memcnn/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /home/hsyang/workspace/20210411_SYS/memcnn-unet/Unet.py in forward(self, x)
#      22
#      23     def forward(self, x):
# ---> 24         return self.double_conv(x)
#      25
#      26
#
# /opt/conda/envs/memcnn/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /opt/conda/envs/memcnn/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# /opt/conda/envs/memcnn/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /home/hsyang/workspace/20210411_SYS/memcnn-unet/InvertCnnConverter.py in forward(self, x)
#      47
#      48     def forward(self, x) :
# ---> 49         x = self.conv2(x)
#      50         x = self.down_channel(x)
#      51         return x
#
# /opt/conda/envs/memcnn/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /opt/conda/envs/memcnn/lib/python3.6/site-packages/memcnn/models/revop.py in forward(self, *xin)
#     199                 self.preserve_rng_state,
#     200                 len(xin),
# --> 201                 *(xin + tuple([p for p in self._fn.parameters() if p.requires_grad])))
#     202         else:
#     203             y = self._fn(*xin)
#
# /opt/conda/envs/memcnn/lib/python3.6/traceback.py in format_stack(f, limit)
#     195     if f is None:
#     196         f = sys._getframe().f_back
# --> 197     return format_list(extract_stack(f, limit=limit))
#     198
#     199
#
# /opt/conda/envs/memcnn/lib/python3.6/traceback.py in extract_stack(f, limit)
#     209     if f is None:
#     210         f = sys._getframe().f_back
# --> 211     stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212     stack.reverse()
#     213     return stack
#
# /opt/conda/envs/memcnn/lib/python3.6/traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     358                 filename, lineno, name, lookup_line=False, locals=f_locals))
#     359         for filename in fnames:
# --> 360             linecache.checkcache(filename)
#     361         # If immediate lookup was desired, trigger lookups now.
#     362         if lookup_lines:
#
# /opt/conda/envs/memcnn/lib/python3.6/site-packages/IPython/core/compilerop.py in check_linecache_ipython(*args)
#     155     """
#     156     # First call the original checkcache as intended
# --> 157     linecache._checkcache_ori(*args)
#     158     # Then, update back the cache with our data, so that tracebacks related
#     159     # to our compiled codes can be produced.
#
# /opt/conda/envs/memcnn/lib/python3.6/linecache.py in checkcache(filename)
#      72             continue   # no-op for files loaded via a __loader__
#      73         try:
# ---> 74             stat = os.stat(fullname)
#      75         except OSError:
#      76             del cache[filename]
#
# KeyboardInterrupt:
